# %%
import pandas as pd
import numpy as np
import cv2
from tensorflow.keras.backend import expand_dims

# %%
image_test = cv2.imread('IMG_5023.jpeg',)

# %%
import matplotlib.pyplot as plt
plt.imshow(image_test)

# %%
img_gray = cv2.cvtColor(image_test, cv2.COLOR_BGR2GRAY)

# %%
plt.imshow(img_gray,cmap='gray')

# %%
img_gray.shape
# Out:
# (384, 683)

# %%
type(img_gray)
# Out:
# numpy.ndarray

# %%
len(img_gray[2])
# Out:
# 683

# %%
# def black_white(array):
#     if array >= 90:
#         return 255
#     return 1

# %%
# black_white_vector = np.vectorize(black_white)
# new_image = black_white_vector(img_gray)

# %%
ret, thresh = cv2.threshold(img_gray,128,255,0)

# %%
# find the contours from the thresholded image
contours, hierarchy = cv2.findContours(thresh, cv2.RETR_TREE, cv2.CHAIN_APPROX_NONE)

print(contours[4])
# Out:
# [[[179  65]]
#
#  [[180  64]]
#
#  [[181  64]]
#
#  ...
#
#  [[176  65]]
#
#  [[177  65]]
#
#  [[178  65]]]

# %%
cv2.drawContours(image_test, contours, 3, (0, 255, 0), 3)
# Out:
# array([[[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         ...,
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0]],
#
#        [[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         ...,
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0]],
#
#        [[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         ...,
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0]],
#
#        ...,
#
#        [[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         ...,
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0]],
#
#        [[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
#         ...,
#         [  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0]],
#
#        [[  0, 255,   0],
#         [  0, 255,   0],
#         [  0, 255,   0],
# ...

# %%
plt.imshow(image_test,cmap='gray')

# %%
c = max(contours,key = cv.contourArea)
x,y,w,h = cv2.boundingRect
